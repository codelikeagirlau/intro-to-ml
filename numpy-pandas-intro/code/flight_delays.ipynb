# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/petergoodin/general_stuff/master/flights.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER  \
# 0           0  2015      1    1            4      AS             98
# 1           1  2015      1    1            4      AA           2336
# 2           2  2015      1    1            4      US            840
# 3           3  2015      1    1            4      AA            258
# 4           4  2015      1    1            4      AS            135
#
#   TAIL_NUMBER ORIGIN_AIRPORT DESTINATION_AIRPORT      ...        ARRIVAL_TIME  \
# 0      N407AS            ANC                 SEA      ...               408.0
# 1      N3KUAA            LAX                 PBI      ...               741.0
# 2      N171US            SFO                 CLT      ...               811.0
# 3      N3HYAA            LAX                 MIA      ...               756.0
# 4      N527AS            SEA                 ANC      ...               259.0
#
#    ARRIVAL_DELAY  DIVERTED  CANCELLED  CANCELLATION_REASON  AIR_SYSTEM_DELAY  \
# ...

# %%
df.tail()
# Out:
#         Unnamed: 0  YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER  \
# 149995      149995  2015      1   10            6      EV           4607
# 149996      149996  2015      1   10            6      WN           4388
# 149997      149997  2015      1   10            6      WN           2903
# 149998      149998  2015      1   10            6      WN           4519
# 149999      149999  2015      1   10            6      WN           2492
#
#        TAIL_NUMBER ORIGIN_AIRPORT DESTINATION_AIRPORT      ...        \
# 149995      N15572            XNA                 IAH      ...
# 149996      N7723E            ATL                 DAL      ...
# 149997      N218WN            ATL                 DCA      ...
# 149998      N436WN            ATL                 MCO      ...
# 149999      N940WN            ATL                 MSY      ...
#
#         ARRIVAL_TIME  ARRIVAL_DELAY  DIVERTED  CANCELLED  CANCELLATION_REASON  \
# ...

# %%
#Drop the Unnamed: 0 col
# df.drop(labels = ['Unnamed: 0'], axis = 1, inplace = True)
df.head()
# Out:
#    YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0  2015      1    1            4      AS             98      N407AS
# 1  2015      1    1            4      AA           2336      N3KUAA
# 2  2015      1    1            4      US            840      N171US
# 3  2015      1    1            4      AA            258      N3HYAA
# 4  2015      1    1            4      AS            135      N527AS
#
#   ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE      ...        \
# 0            ANC                 SEA                    5      ...
# 1            LAX                 PBI                   10      ...
# 2            SFO                 CLT                   20      ...
# 3            LAX                 MIA                   20      ...
# 4            SEA                 ANC                   25      ...
#
#    ARRIVAL_TIME  ARRIVAL_DELAY  DIVERTED  CANCELLED  CANCELLATION_REASON  \
# ...

# %%
#Check unique airline codes
df['AIRLINE'].unique()
# Out:
# array(['AS', 'AA', 'US', 'DL', 'NK', 'UA', 'HA', 'B6', 'OO', 'EV', 'MQ',
#        'F9', 'WN', 'VX'], dtype=object)

# %%
#Select only those relevant to the question
df_new = df[(df['AIRLINE'] == 'AA') | (df['AIRLINE'] == 'B6') | (df['AIRLINE'] == 'DL')]
df_new.head()
# Out:
#    Unnamed: 0  YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER  \
# 1           1  2015      1    1            4      AA           2336
# 3           3  2015      1    1            4      AA            258
# 5           5  2015      1    1            4      DL            806
# 8           8  2015      1    1            4      AA           1112
# 9           9  2015      1    1            4      DL           1173
#
#   TAIL_NUMBER ORIGIN_AIRPORT DESTINATION_AIRPORT      ...        ARRIVAL_TIME  \
# 1      N3KUAA            LAX                 PBI      ...               741.0
# 3      N3HYAA            LAX                 MIA      ...               756.0
# 5      N3730B            SFO                 MSP      ...               610.0
# 8      N3LAAA            SFO                 DFW      ...               532.0
# 9      N826DN            LAS                 ATL      ...               656.0
#
#    ARRIVAL_DELAY  DIVERTED  CANCELLED  CANCELLATION_REASON  AIR_SYSTEM_DELAY  \
# ...

# %%
#Now what?
df_new.groupby(by = ['AIRLINE'])['ARRIVAL_DELAY'].mean()
# Out:
# AIRLINE
# AA    19.511626
# B6    17.202638
# DL     3.891158
# Name: ARRIVAL_DELAY, dtype: float64

# %% [markdown]
# ## So? Who performed better?
